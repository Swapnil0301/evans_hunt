# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"C:\Users\SWAPNIL\Desktop\yacht_hydrodynamics.xlsx",names=["Longitudinal pos","Prismatic coef","Length-displacement ratio","Beam-draught ratio","Length-beam ratio","Froude number","Residuary resistance per unit weight of displacement"])

# %%
mydata
# Out:
#      Longitudinal pos  Prismatic coef  Length-displacement ratio  \
# 0                -2.3           0.568                       4.78
# 1                -2.3           0.568                       4.78
# 2                -2.3           0.568                       4.78
# 3                -2.3           0.568                       4.78
# 4                -2.3           0.568                       4.78
# 5                -2.3           0.568                       4.78
# 6                -2.3           0.568                       4.78
# 7                -2.3           0.568                       4.78
# 8                -2.3           0.568                       4.78
# 9                -2.3           0.568                       4.78
# 10               -2.3           0.568                       4.78
# 11               -2.3           0.568                       4.78
# 12               -2.3           0.568                       4.78
# ...

# %%
X=mydata.drop(["Residuary resistance per unit weight of displacement"],axis=1)

# %%
Y=mydata["Residuary resistance per unit weight of displacement"]

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
myobj=LinearRegression()

# %%
mymodel=myobj.fit(Xtrain,Ytrain)

# %%
Ya=Ytest

# %%
Yp=mymodel.predict(Xtest)

# %%
m=mymodel.coef_

# %%
b=mymodel.intercept_

# %%
m
# Out:
# array([   0.14954259,  -23.77214039,    5.30993766,   -1.17318555,
#          -6.0581431 ,  125.64983359])

# %%
b
# Out:
# -13.333263658451566

# %%
#Yp=m*X+b

# %%
from sklearn import metrics
import numpy as np

# %%
error=metrics.mean_squared_error(Ya,Yp)
np.sqrt(error)
# Out:
# 8.0985016674742027

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 7 columns):
# Longitudinal pos                                        307 non-null float64
# Prismatic coef                                          307 non-null float64
# Length-displacement ratio                               307 non-null float64
# Beam-draught ratio                                      307 non-null float64
# Length-beam ratio                                       307 non-null float64
# Froude number                                           307 non-null float64
# Residuary resistance per unit weight of displacement    307 non-null float64
# dtypes: float64(7)
# memory usage: 16.9 KB
